# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-256-g43c43d8 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# !unzip -q /content/test_data.zip -d ../

# %%
# !unzip -q /content/train_data.zip -d ../

# %%
# !python train.py  --batch 10 --epochs 75 --data custom_data.yaml --weights yolov5s.pt --nosave --cache
# Out:
# 2024-01-02 05:00:12.564302: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-02 05:00:12.564364: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-02 05:00:12.565729: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --conf 0.25 --source /content/test_data
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/test_data, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-256-g43c43d8 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7082944 parameters, 0 gradients, 16.0 GFLOPs
# image 1/81 /content/test_data/00001.jpg: 640x640 1 ALL_MOTOR_VEHICLE_PROHIBITED, 11.7ms
# image 2/81 /content/test_data/00002.jpg: 640x576 1 ALL_MOTOR_VEHICLE_PROHIBITED, 49.6ms
# image 3/81 /content/test_data/00003.jpg: 352x640 1 ALL_MOTOR_VEHICLE_PROHIBITED, 48.0ms
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/last.pt --conf 0.25 --source /content/test_data
# Out:
# detect: weights=['runs/train/exp2/weights/last.pt'], source=/content/test_data, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-254-gba63208 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7082944 parameters, 0 gradients, 16.0 GFLOPs
# image 1/81 /content/test_data/00001.jpg: 640x640 1 ALL_MOTOR_VEHICLE_PROHIBITED, 11.7ms
# image 2/81 /content/test_data/00002.jpg: 640x576 1 ALL_MOTOR_VEHICLE_PROHIBITED, 50.5ms
# image 3/81 /content/test_data/00003.jpg: 352x640 1 ALL_MOTOR_VEHICLE_PROHIBITED, 50.9ms
# ...

# %%
# !zip -r /content/result_data.zip /content/yolov5/runs/detect/exp
# Out:
#   adding: content/yolov5/runs/detect/exp/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp/07012.jpg (deflated 4%)
#   adding: content/yolov5/runs/detect/exp/07008.jpg (deflated 6%)
#   adding: content/yolov5/runs/detect/exp/00015.jpg (deflated 4%)
#   adding: content/yolov5/runs/detect/exp/06001.jpg (deflated 7%)
#   adding: content/yolov5/runs/detect/exp/09006.jpg (deflated 5%)
#   adding: content/yolov5/runs/detect/exp/06019.jpg (deflated 7%)
#   adding: content/yolov5/runs/detect/exp/07015.jpg (deflated 7%)
#   adding: content/yolov5/runs/detect/exp/00016.jpg (deflated 6%)
#   adding: content/yolov5/runs/detect/exp/08027.jpg (deflated 5%)
#   adding: content/yolov5/runs/detect/exp/08032.jpg (deflated 4%)
#   adding: content/yolov5/runs/detect/exp/09008.jpg (deflated 6%)
#   adding: content/yolov5/runs/detect/exp/00012.jpg (deflated 6%)
#   adding: content/yolov5/runs/detect/exp/06002.jpg (deflated 7%)
#   adding: content/yolov5/runs/detect/exp/00003.jpg (deflated 9%)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --conf 0.25 --source /content/test_data1
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/test_data1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-256-g43c43d8 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7082944 parameters, 0 gradients, 16.0 GFLOPs
# image 1/91 /content/test_data1/00001.jpg: 640x640 1 ALL_MOTOR_VEHICLE_PROHIBITED, 11.7ms
# image 2/91 /content/test_data1/00002.jpg: 640x576 1 ALL_MOTOR_VEHICLE_PROHIBITED, 49.5ms
# image 3/91 /content/test_data1/00003.jpg: 352x640 1 ALL_MOTOR_VEHICLE_PROHIBITED, 46.5ms
# ...

# %%
# !unzip -q /content/test_data1.zip -d ../

# %%
# !zip -r /content/result_data1.zip /content/yolov5/runs/detect/exp
# Out:
#   adding: content/yolov5/runs/detect/exp/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp/07012.jpg (deflated 4%)
#   adding: content/yolov5/runs/detect/exp/74049.jpg (deflated 7%)
#   adding: content/yolov5/runs/detect/exp/74051.jpg (deflated 8%)
#   adding: content/yolov5/runs/detect/exp/67070.jpg (deflated 5%)
#   adding: content/yolov5/runs/detect/exp/07008.jpg (deflated 6%)
#   adding: content/yolov5/runs/detect/exp/00015.jpg (deflated 4%)
#   adding: content/yolov5/runs/detect/exp/81039.jpg (deflated 7%)
#   adding: content/yolov5/runs/detect/exp/07015.jpg (deflated 7%)
#   adding: content/yolov5/runs/detect/exp/42089.jpg (deflated 6%)
#   adding: content/yolov5/runs/detect/exp/00016.jpg (deflated 6%)
#   adding: content/yolov5/runs/detect/exp/08027.jpg (deflated 5%)
#   adding: content/yolov5/runs/detect/exp/08032.jpg (deflated 4%)
#   adding: content/yolov5/runs/detect/exp/00012.jpg (deflated 6%)
#   adding: content/yolov5/runs/detect/exp/43035.jpg (deflated 5%)
# ...
